# %%
import xarray as xr
import netCDF4 as nc
import numpy as np

# %%
ds = xr.open_dataset('NorthAtlanticBathmetry')
kw = {'levels': np.arange(-1100,5,100)}
ds.elevation.plot.contourf(**kw)

# %%
lat_val = ds.lat.values[0]
lon_val = ds.lon.values[0]

# %%
float(ds.sel(lat=lat_val, lon=lon_val).elevation.values)
# Out:
# -497.0
