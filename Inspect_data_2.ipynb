# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import xarray as xr
from All_functions.WOD_data_request import *
from All_functions.preprocess_df_stored import *

# %%
ds = WOD_whole_process(year_range=[2018], sensor_type_range=['ctd'], save=False)
# Out:
# /home/hqn21001/Final_Project/marn5895_project/All_functions/WOD_data_request.py:44: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(var_rewrite_array)

# %%
ds['lat'].values
# Out:
# array([44.6937, 44.6937, 44.9307, ..., 47.546 , 44.6937, 44.2675],
#       dtype=float32)

# %%
ds = request_data_from_url(year=2018, sensor_type='pfl')

# %%
ds.reset_index(drop=True, inplace=True)
for i,x in enumerate(ds.Salinity):
    if x[0] == 3.227:
        print(i)

# %%
ds[[(x.month==1)&(x.day==1) for x in ds.time]]
# Out:
#            lat        lon                       time  \
# 54   31.799770 -56.213848 2018-01-01 03:50:38.040733
# 73   41.740196 -64.296295 2018-01-01 04:55:18.838835
# 102  30.236731 -58.629101 2018-01-01 05:40:18.838835
# 104  41.815334 -61.093655 2018-01-01 05:54:21.960554
# 110  59.240932 -52.750961 2018-01-01 06:02:48.840122
# 141  31.492790 -73.360931 2018-01-01 06:19:41.159878
# 197  58.373066 -55.962101 2018-01-01 08:40:18.840122
# 200  40.793133 -50.813477 2018-01-01 09:45:00.000000
# 213  43.497002 -58.459999 2018-01-01 09:25:18.840122
# 227  34.753212 -53.197220 2018-01-01 10:32:48.840122
# 243  58.392570 -57.016525 2018-01-01 10:58:08.038158
# 247  57.097874 -59.866566 2018-01-01 11:06:32.761230
# 362  40.530472 -61.231739 2018-01-01 17:48:46.441956
# 432  34.164001 -64.275002 2018-01-01 21:05:38.040733
#
#                                                 Oxygen  \
# 54                                             [-9999]
# ...

# %%
ds.iloc[197,:].Salinity
# Out:
# array([31.381905, 31.382904, 31.382904, 31.386904, 31.387905, 31.414906,
#        31.613905, 32.016903, 32.639908, 32.85291 , 32.94491 , 33.40691 ,
#        34.19199 , 34.714924, 34.894917, 34.844917, 35.605957, 35.590958,
#        35.693974, 35.745983, 35.749985, 35.73098 , 35.701973, 35.68197 ,
#        35.669968, 35.635963, 35.592953, 35.572952, 35.552948, 35.50894 ,
#        35.454937, 35.384926, 35.368927, 35.341923, 35.272915, 35.258915,
#        35.214912, 35.187912, 35.18391 , 35.17991 , 35.17091 , 35.133907,
#        35.136906, 35.113903, 35.099903, 35.079903, 35.0569  , 35.0429  ,
#        35.0299  , 35.0239  , 35.018898, 35.0179  , 35.016895, 35.013897,
#        35.011898, 35.004898, 34.993896, 34.986897, 34.978897, 34.9749  ,
#        34.9729  , 34.969902, 34.9669  , 34.9639  , 34.9609  , 34.9599  ,
#        34.9589  , 34.9589  , 34.9589  , 34.955902, 34.9589  , 34.9579  ,
#        34.961906, 34.962906, 34.961906, 34.962906, 34.961906, 34.960903,
# ...

# %%
WOD_whole_process(year_range=[2018], sensor_type_range=['pfl'], save=True)

# %%
df2 = pd.read_csv('/shared/marn5895/data/HungJosiahProject/WOD_NWA_2018_pfl.csv')
new_df2 = process_df(df2, inspect=True)
# Out:
# Temperature
# Salinity
# z
# Oxygen
# Chlorophyll
